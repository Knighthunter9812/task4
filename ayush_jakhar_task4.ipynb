# %%
import pandas as pd
path="C:\\Users\\ayush\\Downloads\\task_4.csv"
df=pd.read_csv(path)
#print(df.to_string())

# %%
df
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad  guestroom  \
# 0    13300000  7420.0       4.0        NaN      3.0      NaN        NaN
# 1    12250000  8960.0       NaN        4.0      4.0      yes         no
# 2    12250000  9960.0       3.0        2.0      2.0      yes        NaN
# 3    12215000  7500.0       NaN        NaN      NaN      NaN         no
# 4    11410000  7420.0       NaN        1.0      2.0      NaN  Of course
# ..        ...     ...       ...        ...      ...      ...        ...
# 540   1820000     NaN       2.0        NaN      1.0      NaN         no
# 541   1767150     NaN       3.0        1.0      1.0       no       ille
# 542   1750000  3620.0       NaN        NaN      NaN      yes         no
# 543   1750000     NaN       NaN        1.0      1.0       no         no
# 544   1750000  3850.0       3.0        1.0      2.0      NaN        NaN
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# 0        NaN             NaN             yes      2.0   Haanji
# 1         no           Nakko             yes      NaN       no
# 2        yes              no           Naaji      2.0      yes
# 3        yes              no             yes      3.0      yes
# 4        yes             NaN             yes      2.0       no
# ..       ...             ...             ...      ...      ...
# 540      NaN              no              no      NaN       no
# 541       no              no             Nah      NaN      NaN
# 542       no             NaN             NaN      NaN        n
# 543       no              no              no      0.0      NaN
# 544      NaN             NaN              no      0.0    Naaji
#
#     furnishingstatus
# 0          furnished
# 1          furnished
# 2     semi-furnished
# 3          furnished
# 4                NaN
# ..               ...
# 540      unfurnished
# 541              NaN
# 542      unfurnished
# 543        furnished
# 544              NaN
#
# [545 rows x 13 columns]

# %%
#checking number of null values
df.isnull().sum()
# Out:
# price                 0
# area                206
# bedrooms            187
# bathrooms           183
# stories             185
# mainroad            194
# guestroom           210
# basement            204
# hotwaterheating     204
# airconditioning     188
# parking             208
# prefarea            188
# furnishingstatus    187
# dtype: int64

# %%
#print null values of column area
df[df['area'].isna()==1]
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad  guestroom  \
# 5    10850000   NaN       NaN        NaN      NaN      NaN         no
# 6    10150000   NaN       4.0        NaN      4.0      yes         no
# 11    9681000   NaN       NaN        NaN      NaN      yes  Of course
# 15    9100000   NaN       4.0        NaN      2.0      NaN        NaN
# 16    9100000   NaN       NaN        2.0      2.0      yes        NaN
# ..        ...   ...       ...        ...      ...      ...        ...
# 537   1890000   NaN       3.0        NaN      2.0      yes        NaN
# 539   1855000   NaN       2.0        NaN      NaN      NaN         no
# 540   1820000   NaN       2.0        NaN      1.0      NaN         no
# 541   1767150   NaN       3.0        1.0      1.0       no       ille
# 543   1750000   NaN       NaN        1.0      1.0       no         no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# 5     Haanji              no             yes      NaN      yes
# 6        NaN             NaN             yes      NaN      yes
# 11       NaN             NaN             NaN      2.0      NaN
# 15       NaN              no              no      2.0       no
# 16       NaN              no             yes      NaN      yes
# ..       ...             ...             ...      ...      ...
# 537    Naaji              no              no      NaN      NaN
# 539       no             NaN             NaN      NaN       no
# 540      NaN              no              no      NaN       no
# 541       no              no             Nah      NaN      NaN
# 543       no              no              no      0.0      NaN
#
#     furnishingstatus
# 5     semi-furnished
# 6     semi-furnished
# 11    semi-furnished
# 15    semi-furnished
# 16       unfurnished
# ..               ...
# 537              NaN
# 539              NaN
# 540      unfurnished
# 541              NaN
# 543        furnished
#
# [206 rows x 13 columns]

# %%
#check for duplicate values
df.duplicated().any()
# Out:
# False

# %%
#print number of duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
#print datatype of different column
df.dtypes
# Out:
# price                 int64
# area                float64
# bedrooms            float64
# bathrooms           float64
# stories             float64
# mainroad             object
# guestroom            object
# basement             object
# hotwaterheating      object
# airconditioning      object
# parking             float64
# prefarea             object
# furnishingstatus     object
# dtype: object

# %%
#convert datatype
#df['parking'].astype('int')

# %%
#o access rows
# df=df.drop(0,axis=0)
# df
#to access column
# df=df.drop('price',axis=1)
# df

# %%
print(df['stories'].unique())
print(df['bedrooms'].unique())
print(df['bathrooms'].unique())
print(df['mainroad'].unique())
print(df['guestroom'].unique())
print(df['basement'].unique())
print(df['hotwaterheating'].unique())
print(df['airconditioning'].unique())
print(df['parking'].unique())
print(df['prefarea'].unique())
print(df['furnishingstatus'].unique())
# Out:
# [ 3.  4.  2. nan  1.]
# [ 4. nan  3.  5.  2.  6.  1.]
# [nan  4.  2.  1.  3.]
# [nan 'yes' 'Of course' 'Indeed' 'yep' 'Haan' 'True' 'y' 'Y' "['y']" 'Nope'
#  'Yo' 'no' 'Haanji' 'Nakko' 'False' 'Naaji' 'N' 'n']
# [nan 'no' 'Of course' 'yes' 'ille' 'y' 'N' 'Yo' 'Nakko' 'Y' 'Naaji' 'n'
#  'False' "['n']" 'Haan' 'Nah' 'yep' 'Haanji' 'True' 'Nope' 'Indeed']
# [nan 'no' 'yes' 'Haanji' 'N' 'Naaji' 'n' 'y' 'False' 'Haan' 'Nakko' 'ille'
#  'Nah' 'True' 'yep' 'Nope' 'Indeed' "['n']" 'Of course' 'Y' 'Yo']
# [nan 'Nakko' 'no' 'Nope' 'yes' 'Nah' 'Y' 'n' 'False' 'Naaji' 'ille' 'N'
#  "['n']" 'Haan' 'y']
# ['yes' 'Naaji' 'no' nan 'yep' 'y' 'True' "['y']" 'Y' "['n']" 'n' 'N'
#  'Nakko' 'Nah' 'ille' 'False' 'Nope' 'Of course' 'Haanji']
# [ 2. nan  3.  0.  1.]
# ['Haanji' 'no' 'yes' 'Haan' nan 'Of course' 'Nakko' 'Nope' 'ille' 'N'
#  'yep' 'y' 'Naaji' 'True' 'Y' 'n' "['n']" 'False' 'Yo' 'Nah']
# ['furnished' 'semi-furnished' nan 'unfurnished']

# %%
#null_values=["nan","Of course" ,"Indeed", "yep" ,"Haan" ,"True" ,"y", "Y", "['y']"," Nope","Yo","Haanji","Nakko","False" ,"Naaji", "N" ,"n","ille","N","['n']","Nah"]

# %%
#df=pd.read_csv(path,na_values=null_values)

# %%
#df.isnull().sum()

# %%
#replacing null values
wtrue=["Of course" ,"Indeed", "yep" ,"Haan" ,"True" ,"y", "Y", "['y']","Yo","Haanji"]
rtrue='yes'
wfalse=["Nope","Nakko","False" ,"Naaji", "N" ,"n","ille","N","['n']","Nah"]
rfalse='no'
df['mainroad']=df['mainroad'].replace(wtrue,rtrue)
df['mainroad']=df['mainroad'].replace(wfalse,rfalse)
df['guestroom']=df['guestroom'].replace(wtrue,rtrue)
df['guestroom']=df['guestroom'].replace(wfalse,rfalse)
df['basement']=df['basement'].replace(wtrue,rtrue)
df['basement']=df['basement'].replace(wfalse,rfalse)
df['hotwaterheating']=df['hotwaterheating'].replace(wtrue,rtrue)
df['hotwaterheating']=df['hotwaterheating'].replace(wfalse,rfalse)
df['airconditioning']=df['airconditioning'].replace(wtrue,rtrue)
df['airconditioning']=df['airconditioning'].replace(wfalse,rfalse)
df['parking']=df['parking'].replace(wtrue,rtrue)
df['parking']=df['parking'].replace(wfalse,rfalse)
df['prefarea']=df['prefarea'].replace(wtrue,rtrue)
df['prefarea']=df['prefarea'].replace(wfalse,rfalse)

# %%
#to display specific columns
#display(df.iloc[6])

# %%
#display number of null values
df.isnull().sum()
# Out:
# price                 0
# area                206
# bedrooms            187
# bathrooms           183
# stories             185
# mainroad            194
# guestroom           210
# basement            204
# hotwaterheating     204
# airconditioning     188
# parking             208
# prefarea            188
# furnishingstatus    187
# dtype: int64

# %%
#replacing null values
df=df.fillna({
    'parking':0,
    'bedrooms':1,
    'bathrooms':1,
    'stories':1,
    #'basement':'no'
    #'prefarea':'no'
    
})

# %%
#dropping columns with null values
df=df.dropna(subset=['furnishingstatus'])
df=df.dropna(subset=['airconditioning'])
df=df.dropna(subset=['hotwaterheating'])
df=df.dropna(subset=['guestroom'])
#df=df.dropna(subset=['area'])
df=df.dropna(subset=['mainroad'])
df
# Out:
#         price     area  bedrooms  bathrooms  stories mainroad guestroom  \
# 1    12250000   8960.0       1.0        4.0      4.0      yes        no
# 13    9240000   3500.0       4.0        1.0      1.0      yes        no
# 29    8400000      NaN       4.0        1.0      2.0      yes        no
# 31    8400000   7000.0       3.0        1.0      4.0      yes        no
# 44    7560000   6000.0       4.0        1.0      4.0      yes        no
# 56    7343000      NaN       1.0        1.0      2.0      yes        no
# 64    7000000  11175.0       1.0        1.0      1.0      yes        no
# 69    6790000      NaN       1.0        2.0      2.0      yes        no
# 73    6685000   6600.0       2.0        2.0      4.0      yes        no
# 77    6650000   6500.0       3.0        1.0      1.0      yes        no
# 96    6300000   9000.0       3.0        1.0      1.0      yes        no
# 103   6195000   6350.0       1.0        1.0      3.0      yes       yes
# 111   6090000      NaN       1.0        1.0      3.0      yes        no
# 132   5810000      NaN       1.0        1.0      3.0      yes        no
# 133   5810000      NaN       1.0        1.0      3.0      yes        no
# 136   5740000   5400.0       4.0        2.0      1.0      yes        no
# 143   5600000      NaN       5.0        2.0      3.0       no        no
# 149   5600000      NaN       4.0        2.0      1.0      yes        no
# 154   5530000   3650.0       3.0        2.0      1.0      yes        no
# 164   5390000   6710.0       1.0        2.0      1.0      yes       yes
# 166   5320000   7800.0       3.0        1.0      1.0      yes        no
# 195   4970000   4410.0       4.0        3.0      1.0      yes        no
# 203   4900000      NaN       1.0        1.0      2.0      yes        no
# 205   4900000      NaN       1.0        1.0      1.0      yes        no
# 223   4760000   6321.0       1.0        1.0      2.0      yes        no
# 224   4760000  10240.0       1.0        1.0      1.0      yes        no
# 236   4620000   2870.0       2.0        1.0      1.0      yes       yes
# 246   4550000      NaN       3.0        1.0      1.0      yes        no
# 256   4480000   4000.0       3.0        1.0      1.0      yes        no
# 273   4340000   3500.0       4.0        1.0      2.0      yes        no
# 282   4270000      NaN       1.0        1.0      2.0       no       yes
# 289   4200000   5850.0       2.0        1.0      1.0      yes       yes
# 294   4200000      NaN       4.0        1.0      2.0       no        no
# 299   4200000      NaN       3.0        1.0      1.0      yes        no
# 313   4095000   3680.0       1.0        1.0      2.0      yes        no
# 321   4025000      NaN       1.0        2.0      1.0      yes        no
# 329   3990000   3960.0       1.0        1.0      1.0      yes        no
# 349   3780000   4820.0       3.0        1.0      1.0      yes        no
# 358   3745000      NaN       2.0        1.0      1.0      yes        no
# 374   3640000   3520.0       1.0        1.0      1.0      yes        no
# 380   3605000   4500.0       1.0        1.0      1.0      yes        no
# 381   3605000   4000.0       1.0        1.0      1.0      yes        no
# 385   3570000      NaN       2.0        1.0      1.0      yes        no
# 387   3500000   4240.0       1.0        1.0      2.0      yes        no
# 388   3500000      NaN       1.0        1.0      1.0      yes        no
# 390   3500000   2135.0       3.0        1.0      1.0       no        no
# 401   3500000   9500.0       1.0        1.0      1.0      yes        no
# 406   3465000   5320.0       2.0        1.0      1.0      yes        no
# 410   3430000      NaN       1.0        1.0      1.0      yes        no
# 457   3115000   3000.0       3.0        1.0      1.0       no        no
# 458   3115000   3850.0       3.0        1.0      1.0      yes        no
# 462   3080000      NaN       3.0        1.0      2.0       no        no
# 467   3010000   3240.0       3.0        1.0      1.0      yes        no
# 479   2940000      NaN       4.0        1.0      1.0       no        no
# 484   2870000   3040.0       2.0        1.0      1.0       no        no
# 521   2408000   3635.0       2.0        1.0      1.0       no        no
# 524   2380000   3264.0       1.0        1.0      1.0      yes        no
# 531   2233000   5300.0       3.0        1.0      1.0       no        no
# 543   1750000      NaN       1.0        1.0      1.0       no        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# 1         no              no             yes      0.0       no
# 13        no             yes              no      2.0       no
# 29       yes              no             yes      1.0      yes
# 31        no              no             yes      2.0      NaN
# 44        no              no             yes      1.0      NaN
# 56       yes              no              no      0.0      yes
# 64       yes              no             yes      0.0      NaN
# 69       NaN              no              no      2.0      NaN
# 73       NaN              no              no      0.0      yes
# 77       NaN              no             yes      0.0      yes
# 96       yes              no              no      1.0      yes
# 103      NaN              no             yes      0.0       no
# 111       no              no             yes      2.0       no
# 132      NaN              no             yes      0.0      NaN
# 133      NaN              no             yes      0.0       no
# 136       no              no             yes      2.0       no
# 143      yes             yes              no      0.0      NaN
# 149      yes              no              no      0.0      yes
# 154      NaN              no              no      0.0       no
# 164      yes              no              no      1.0      NaN
# 166      NaN              no             yes      2.0      yes
# 195      NaN              no              no      2.0      NaN
# 203      NaN              no              no      0.0       no
# 205       no              no             yes      2.0       no
# 223      yes              no             yes      0.0      NaN
# 224      NaN              no             yes      0.0      yes
# 236      NaN              no              no      0.0      NaN
# 246      NaN              no              no      0.0      yes
# 256      NaN              no              no      2.0       no
# 273       no              no              no      0.0      NaN
# 282      yes              no             yes      0.0       no
# 289      yes              no              no      2.0      NaN
# 294       no              no              no      0.0       no
# 299      NaN              no              no      3.0       no
# 313       no              no              no      0.0       no
# 321       no             yes              no      2.0      NaN
# 329       no              no              no      0.0       no
# 349       no              no              no      0.0      NaN
# 358       no              no              no      0.0      yes
# 374      NaN              no              no      0.0       no
# 380      NaN              no              no      0.0       no
# 381       no              no              no      0.0      NaN
# 385       no              no              no      0.0       no
# 387       no              no             yes      0.0      NaN
# 388       no              no              no      0.0       no
# 390      NaN              no              no      0.0      NaN
# 401      NaN              no              no      0.0      NaN
# 406      NaN              no              no      0.0      yes
# 410       no              no              no      0.0       no
# 457      NaN              no             yes      0.0      NaN
# 458       no              no              no      0.0      NaN
# 462      yes              no              no      0.0      NaN
# 467       no              no              no      0.0       no
# 479      NaN              no              no      0.0       no
# 484       no              no              no      0.0       no
# 521       no              no              no      0.0       no
# 524       no              no              no      0.0      NaN
# 531       no              no             yes      0.0      yes
# 543       no              no              no      0.0      NaN
#
#     furnishingstatus
# 1          furnished
# 13         furnished
# 29    semi-furnished
# 31    semi-furnished
# 44         furnished
# 56    semi-furnished
# 64         furnished
# 69         furnished
# 73         furnished
# 77         furnished
# 96         furnished
# 103        furnished
# 111      unfurnished
# 132   semi-furnished
# 133      unfurnished
# 136      unfurnished
# 143      unfurnished
# 149   semi-furnished
# 154   semi-furnished
# 164        furnished
# 166      unfurnished
# 195   semi-furnished
# 203   semi-furnished
# 205   semi-furnished
# 223        furnished
# 224      unfurnished
# 236   semi-furnished
# 246   semi-furnished
# 256        furnished
# 273        furnished
# 282      unfurnished
# 289   semi-furnished
# 294   semi-furnished
# 299        furnished
# 313   semi-furnished
# 321   semi-furnished
# 329        furnished
# 349   semi-furnished
# 358   semi-furnished
# 374   semi-furnished
# 380   semi-furnished
# 381   semi-furnished
# 385      unfurnished
# 387   semi-furnished
# 388      unfurnished
# 390      unfurnished
# 401      unfurnished
# 406      unfurnished
# 410      unfurnished
# 457      unfurnished
# 458      unfurnished
# 462   semi-furnished
# 467   semi-furnished
# 479      unfurnished
# 484      unfurnished
# 521      unfurnished
# 524      unfurnished
# 531      unfurnished
# 543        furnished

# %%
#used to fill null values
df['area']=df['area'].interpolate(method='linear')

# %%
df
# Out:
#         price          area  bedrooms  bathrooms  stories mainroad guestroom  \
# 1    12250000   8960.000000       1.0        4.0      4.0      yes        no
# 13    9240000   3500.000000       4.0        1.0      1.0      yes        no
# 29    8400000   5250.000000       4.0        1.0      2.0      yes        no
# 31    8400000   7000.000000       3.0        1.0      4.0      yes        no
# 44    7560000   6000.000000       4.0        1.0      4.0      yes        no
# 56    7343000   8587.500000       1.0        1.0      2.0      yes        no
# 64    7000000  11175.000000       1.0        1.0      1.0      yes        no
# 69    6790000   8887.500000       1.0        2.0      2.0      yes        no
# 73    6685000   6600.000000       2.0        2.0      4.0      yes        no
# 77    6650000   6500.000000       3.0        1.0      1.0      yes        no
# 96    6300000   9000.000000       3.0        1.0      1.0      yes        no
# 103   6195000   6350.000000       1.0        1.0      3.0      yes       yes
# 111   6090000   6112.500000       1.0        1.0      3.0      yes        no
# 132   5810000   5875.000000       1.0        1.0      3.0      yes        no
# 133   5810000   5637.500000       1.0        1.0      3.0      yes        no
# 136   5740000   5400.000000       4.0        2.0      1.0      yes        no
# 143   5600000   4816.666667       5.0        2.0      3.0       no        no
# 149   5600000   4233.333333       4.0        2.0      1.0      yes        no
# 154   5530000   3650.000000       3.0        2.0      1.0      yes        no
# 164   5390000   6710.000000       1.0        2.0      1.0      yes       yes
# 166   5320000   7800.000000       3.0        1.0      1.0      yes        no
# 195   4970000   4410.000000       4.0        3.0      1.0      yes        no
# 203   4900000   5047.000000       1.0        1.0      2.0      yes        no
# 205   4900000   5684.000000       1.0        1.0      1.0      yes        no
# 223   4760000   6321.000000       1.0        1.0      2.0      yes        no
# 224   4760000  10240.000000       1.0        1.0      1.0      yes        no
# 236   4620000   2870.000000       2.0        1.0      1.0      yes       yes
# 246   4550000   3435.000000       3.0        1.0      1.0      yes        no
# 256   4480000   4000.000000       3.0        1.0      1.0      yes        no
# 273   4340000   3500.000000       4.0        1.0      2.0      yes        no
# 282   4270000   4675.000000       1.0        1.0      2.0       no       yes
# 289   4200000   5850.000000       2.0        1.0      1.0      yes       yes
# 294   4200000   5126.666667       4.0        1.0      2.0       no        no
# 299   4200000   4403.333333       3.0        1.0      1.0      yes        no
# 313   4095000   3680.000000       1.0        1.0      2.0      yes        no
# 321   4025000   3820.000000       1.0        2.0      1.0      yes        no
# 329   3990000   3960.000000       1.0        1.0      1.0      yes        no
# 349   3780000   4820.000000       3.0        1.0      1.0      yes        no
# 358   3745000   4170.000000       2.0        1.0      1.0      yes        no
# 374   3640000   3520.000000       1.0        1.0      1.0      yes        no
# 380   3605000   4500.000000       1.0        1.0      1.0      yes        no
# 381   3605000   4000.000000       1.0        1.0      1.0      yes        no
# 385   3570000   4120.000000       2.0        1.0      1.0      yes        no
# 387   3500000   4240.000000       1.0        1.0      2.0      yes        no
# 388   3500000   3187.500000       1.0        1.0      1.0      yes        no
# 390   3500000   2135.000000       3.0        1.0      1.0       no        no
# 401   3500000   9500.000000       1.0        1.0      1.0      yes        no
# 406   3465000   5320.000000       2.0        1.0      1.0      yes        no
# 410   3430000   4160.000000       1.0        1.0      1.0      yes        no
# 457   3115000   3000.000000       3.0        1.0      1.0       no        no
# 458   3115000   3850.000000       3.0        1.0      1.0      yes        no
# 462   3080000   3545.000000       3.0        1.0      2.0       no        no
# 467   3010000   3240.000000       3.0        1.0      1.0      yes        no
# 479   2940000   3140.000000       4.0        1.0      1.0       no        no
# 484   2870000   3040.000000       2.0        1.0      1.0       no        no
# 521   2408000   3635.000000       2.0        1.0      1.0       no        no
# 524   2380000   3264.000000       1.0        1.0      1.0      yes        no
# 531   2233000   5300.000000       3.0        1.0      1.0       no        no
# 543   1750000   5300.000000       1.0        1.0      1.0       no        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# 1         no              no             yes      0.0       no
# 13        no             yes              no      2.0       no
# 29       yes              no             yes      1.0      yes
# 31        no              no             yes      2.0      NaN
# 44        no              no             yes      1.0      NaN
# 56       yes              no              no      0.0      yes
# 64       yes              no             yes      0.0      NaN
# 69       NaN              no              no      2.0      NaN
# 73       NaN              no              no      0.0      yes
# 77       NaN              no             yes      0.0      yes
# 96       yes              no              no      1.0      yes
# 103      NaN              no             yes      0.0       no
# 111       no              no             yes      2.0       no
# 132      NaN              no             yes      0.0      NaN
# 133      NaN              no             yes      0.0       no
# 136       no              no             yes      2.0       no
# 143      yes             yes              no      0.0      NaN
# 149      yes              no              no      0.0      yes
# 154      NaN              no              no      0.0       no
# 164      yes              no              no      1.0      NaN
# 166      NaN              no             yes      2.0      yes
# 195      NaN              no              no      2.0      NaN
# 203      NaN              no              no      0.0       no
# 205       no              no             yes      2.0       no
# 223      yes              no             yes      0.0      NaN
# 224      NaN              no             yes      0.0      yes
# 236      NaN              no              no      0.0      NaN
# 246      NaN              no              no      0.0      yes
# 256      NaN              no              no      2.0       no
# 273       no              no              no      0.0      NaN
# 282      yes              no             yes      0.0       no
# 289      yes              no              no      2.0      NaN
# 294       no              no              no      0.0       no
# 299      NaN              no              no      3.0       no
# 313       no              no              no      0.0       no
# 321       no             yes              no      2.0      NaN
# 329       no              no              no      0.0       no
# 349       no              no              no      0.0      NaN
# 358       no              no              no      0.0      yes
# 374      NaN              no              no      0.0       no
# 380      NaN              no              no      0.0       no
# 381       no              no              no      0.0      NaN
# 385       no              no              no      0.0       no
# 387       no              no             yes      0.0      NaN
# 388       no              no              no      0.0       no
# 390      NaN              no              no      0.0      NaN
# 401      NaN              no              no      0.0      NaN
# 406      NaN              no              no      0.0      yes
# 410       no              no              no      0.0       no
# 457      NaN              no             yes      0.0      NaN
# 458       no              no              no      0.0      NaN
# 462      yes              no              no      0.0      NaN
# 467       no              no              no      0.0       no
# 479      NaN              no              no      0.0       no
# 484       no              no              no      0.0       no
# 521       no              no              no      0.0       no
# 524       no              no              no      0.0      NaN
# 531       no              no             yes      0.0      yes
# 543       no              no              no      0.0      NaN
#
#     furnishingstatus
# 1          furnished
# 13         furnished
# 29    semi-furnished
# 31    semi-furnished
# 44         furnished
# 56    semi-furnished
# 64         furnished
# 69         furnished
# 73         furnished
# 77         furnished
# 96         furnished
# 103        furnished
# 111      unfurnished
# 132   semi-furnished
# 133      unfurnished
# 136      unfurnished
# 143      unfurnished
# 149   semi-furnished
# 154   semi-furnished
# 164        furnished
# 166      unfurnished
# 195   semi-furnished
# 203   semi-furnished
# 205   semi-furnished
# 223        furnished
# 224      unfurnished
# 236   semi-furnished
# 246   semi-furnished
# 256        furnished
# 273        furnished
# 282      unfurnished
# 289   semi-furnished
# 294   semi-furnished
# 299        furnished
# 313   semi-furnished
# 321   semi-furnished
# 329        furnished
# 349   semi-furnished
# 358   semi-furnished
# 374   semi-furnished
# 380   semi-furnished
# 381   semi-furnished
# 385      unfurnished
# 387   semi-furnished
# 388      unfurnished
# 390      unfurnished
# 401      unfurnished
# 406      unfurnished
# 410      unfurnished
# 457      unfurnished
# 458      unfurnished
# 462   semi-furnished
# 467   semi-furnished
# 479      unfurnished
# 484      unfurnished
# 521      unfurnished
# 524      unfurnished
# 531      unfurnished
# 543        furnished

# %%
#exporting the file
df.to_csv('C:\\Users\\ayush\\OneDrive\\Desktop\\ayush_jakhar_task4\\ayush_jakhar_task4.csv')
